# %% [markdown]
# # First
# batch size 2048 lr 5e-4

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSelu'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 2048, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 5 features: ['jetPt', 'jetEta', 'jetMass', 'ntracks', 'ntowers']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'testing.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-7,1e-2], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 2.112s
# ______________________________________

# %%
compileArgs['lr'] = 5e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=10, cosAnnealMult=1, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.491783898685
# 2 New best found: 0.489882329838
# 4 New best found: 0.489098813778
# 6 New best found: 0.488634631575
# 7 New best found: 0.488416921263
# 9 New best found: 0.488337600683
# 12 New best found: 0.488259412228
# 17 New best found: 0.487956088563
# 25 New best found: 0.487951367031
# 34 New best found: 0.487871680217
# 40 New best found: 0.487781575373
# 45 New best found: 0.487685398584
# 54 New best found: 0.487383095077
# Early stopping after 64 epochs
# Score is: {'loss': 0.4873830950772872, 'AUC': 0.2109543826873822}
# Fold took 214.952s
#
# Running fold 2 / 10
# 1 New best found: 0.497623806903
# 2 New best found: 0.493301805792
# 3 New best found: 0.492153657788
# 5 New best found: 0.492008779067
# 6 New best found: 0.491769385982
# 7 New best found: 0.490931321265
# 15 New best found: 0.490802199578
# 16 New best found: 0.490793260434
# 17 New best found: 0.490746660901
# 25 New best found: 0.490614975571
# 27 New best found: 0.490329471668
# 30 New best found: 0.490254371237
# 36 New best found: 0.490228377432
# 38 New best found: 0.4900220003
# 46 New best found: 0.490004517649
# Early stopping after 56 epochs
# Score is: {'loss': 0.49000451764887754, 'AUC': 0.21377706845286948}
# Fold took 202.044s
#
# Running fold 3 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.133102). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.49405667789
# 2 New best found: 0.490954695175
# 4 New best found: 0.490006117778
# 5 New best found: 0.48984730491
# 7 New best found: 0.489818927197
# 9 New best found: 0.489317435274
# 13 New best found: 0.48902250783
# 17 New best found: 0.488800121074
# 24 New best found: 0.48867234246
# 27 New best found: 0.488637466742
# 29 New best found: 0.488575248682
# 32 New best found: 0.488173950998
# Early stopping after 42 epochs
# Score is: {'loss': 0.48817395099810945, 'AUC': 0.21183494697549898}
# Fold took 154.688s
#
# Running fold 4 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.153366). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.491632565054
# 2 New best found: 0.489828769817
# 3 New best found: 0.489219549667
# 4 New best found: 0.488853241719
# 6 New best found: 0.488366722164
# 7 New best found: 0.488361937352
# 8 New best found: 0.488108134039
# 10 New best found: 0.488010591464
# 12 New best found: 0.487966555146
# 14 New best found: 0.487828951047
# 15 New best found: 0.487662086628
# 24 New best found: 0.487614896759
# 25 New best found: 0.487400853423
# 27 New best found: 0.48731568971
# 30 New best found: 0.487233291724
# 35 New best found: 0.487065434323
# Early stopping after 45 epochs
# Score is: {'loss': 0.48706543432287647, 'AUC': 0.2105834417758332}
# Fold took 164.443s
#
# Running fold 5 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.160074). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.492647710718
# 2 New best found: 0.490905811768
# 4 New best found: 0.490526770401
# 6 New best found: 0.489995665
# 8 New best found: 0.489876135331
# 9 New best found: 0.489640295061
# 12 New best found: 0.489606026955
# 13 New best found: 0.489491113164
# 16 New best found: 0.489226045762
# 18 New best found: 0.489125665038
# 26 New best found: 0.488955099728
# 27 New best found: 0.488927084677
# 32 New best found: 0.488917509624
# 33 New best found: 0.488727080257
# Early stopping after 43 epochs
# Score is: {'loss': 0.48872708025739076, 'AUC': 0.21262042006870208}
# Fold took 145.337s
#
# Running fold 6 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.173524). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.492224864527
# 2 New best found: 0.490559129372
# 3 New best found: 0.490213810396
# 4 New best found: 0.489828499205
# 5 New best found: 0.489618020526
# 6 New best found: 0.48926816533
# 10 New best found: 0.489064696188
# 13 New best found: 0.488908101012
# 15 New best found: 0.488748775393
# 21 New best found: 0.488535394919
# Early stopping after 31 epochs
# Score is: {'loss': 0.48853539491866266, 'AUC': 0.21240102773161806}
# Fold took 116.192s
#
# Running fold 7 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.191813). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.492467502342
# 2 New best found: 0.490983835135
# 3 New best found: 0.490556120005
# 4 New best found: 0.490069328944
# 5 New best found: 0.489889508558
# 6 New best found: 0.489628514083
# 7 New best found: 0.489474684455
# 11 New best found: 0.489022326409
# 17 New best found: 0.488782151028
# 27 New best found: 0.48852176729
# Early stopping after 37 epochs
# Score is: {'loss': 0.4885217672902144, 'AUC': 0.21220016127168895}
# Fold took 146.163s
#
# Running fold 8 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.222666). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111708). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.493174316946
# 2 New best found: 0.490766247759
# 3 New best found: 0.49028161144
# 4 New best found: 0.489613800982
# 5 New best found: 0.489168238374
# 7 New best found: 0.489009045567
# 8 New best found: 0.48885897193
# 14 New best found: 0.488855300559
# 17 New best found: 0.488533190634
# 22 New best found: 0.488305157486
# 29 New best found: 0.48817801665
# 33 New best found: 0.488117126661
# 41 New best found: 0.488091198299
# 42 New best found: 0.488085314832
# 46 New best found: 0.488064833723
# 51 New best found: 0.487973319608
# Early stopping after 61 epochs
# Score is: {'loss': 0.4879733196084357, 'AUC': 0.2115988567556426}
# Fold took 232.501s
#
# Running fold 9 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.222755). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111706). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.491150949884
# 2 New best found: 0.489376335217
# 3 New best found: 0.488741598354
# 4 New best found: 0.488602308195
# 5 New best found: 0.488573047518
# 7 New best found: 0.488398887149
# 8 New best found: 0.488317297078
# 9 New best found: 0.488248544046
# 11 New best found: 0.488220392525
# 17 New best found: 0.488089703355
# 21 New best found: 0.487975696566
# 26 New best found: 0.487633896698
# 30 New best found: 0.487582178758
# 35 New best found: 0.487420624823
# 37 New best found: 0.487261342655
# Early stopping after 47 epochs
# Score is: {'loss': 0.48726134265547005, 'AUC': 0.2108139374250717}
# Fold took 191.498s
#
# Running fold 10 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.259885). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.130329). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.497036208464
# 2 New best found: 0.492268890619
# 3 New best found: 0.492188456502
# 5 New best found: 0.491768021315
# 6 New best found: 0.491255613092
# 11 New best found: 0.491241295122
# 12 New best found: 0.490910987255
# 14 New best found: 0.490696113467
# 15 New best found: 0.490678554116
# 16 New best found: 0.490577382712
# 17 New best found: 0.490501472789
# 19 New best found: 0.490470485705
# 21 New best found: 0.490375095779
# Early stopping after 31 epochs
# Score is: {'loss': 0.4903750957786841, 'AUC': 0.21441490562233767}
# Fold took 123.875s
#
#
# ______________________________________
# Training finished
# Cross-validation took 1693.393s
# Mean AUC = 0.2121 +- 0.0004
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=10):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]])
