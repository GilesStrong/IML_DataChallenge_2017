# %% [markdown]
# # Third
# batch size 2048 lr 1e-3 swish

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using Theano backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSwish'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 2048, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 5 features: ['jetPt', 'jetEta', 'jetMass', 'ntracks', 'ntowers']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'testing.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-7,1e-2], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 8.421s
# ______________________________________

# %%
compileArgs['lr'] = 1e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=10, cosAnnealMult=1, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.497428199445
# 2 New best found: 0.49060623672
# 3 New best found: 0.489876724115
# 4 New best found: 0.488691897408
# 5 New best found: 0.488407204543
# 7 New best found: 0.488352863154
# 8 New best found: 0.48806368686
# 10 New best found: 0.48790686949
# 12 New best found: 0.487800483151
# 13 New best found: 0.487664056075
# 15 New best found: 0.487610054984
# 19 New best found: 0.487487872186
# 22 New best found: 0.487420679033
# 23 New best found: 0.487420506369
# 24 New best found: 0.487370044249
# 28 New best found: 0.487367352299
# 29 New best found: 0.487350167259
# 37 New best found: 0.487269673885
# 42 New best found: 0.48725890654
# Early stopping after 52 epochs
# Score is: {'loss': 0.48725890654018117, 'AUC': 0.21074608293381747}
# Fold took 170.328s
#
# Running fold 2 / 10
# 1 New best found: 0.497995550188
# 2 New best found: 0.49219379383
# 3 New best found: 0.491068383815
# 4 New best found: 0.490770925319
# 5 New best found: 0.490558111303
# 6 New best found: 0.490305937321
# 8 New best found: 0.490185147432
# 9 New best found: 0.49007700708
# 11 New best found: 0.490025276865
# 15 New best found: 0.489978502094
# 17 New best found: 0.489962331244
# 21 New best found: 0.489892775694
# 24 New best found: 0.489737369122
# 33 New best found: 0.489664840363
# Early stopping after 43 epochs
# Score is: {'loss': 0.48966484036253755, 'AUC': 0.21363804844848144}
# Fold took 144.402s
#
# Running fold 3 / 10
# 1 New best found: 0.498175494282
# 2 New best found: 0.490755319596
# 3 New best found: 0.489522974694
# 4 New best found: 0.488953076614
# 6 New best found: 0.488827599571
# 7 New best found: 0.48866633557
# 8 New best found: 0.488283985264
# 10 New best found: 0.488107239827
# 13 New best found: 0.488105816724
# 15 New best found: 0.487888987507
# 17 New best found: 0.487824523643
# 26 New best found: 0.487769187371
# 28 New best found: 0.487701748383
# 37 New best found: 0.487540620484
# Early stopping after 47 epochs
# Score is: {'loss': 0.48754062048435359, 'AUC': 0.21110861177008844}
# Fold took 151.664s
#
# Running fold 4 / 10
# 1 New best found: 0.50226136124
# 2 New best found: 0.493213868628
# 3 New best found: 0.490075928854
# 4 New best found: 0.488789599637
# 5 New best found: 0.488212976541
# 6 New best found: 0.487819859816
# 7 New best found: 0.487799392681
# 8 New best found: 0.487576090031
# 10 New best found: 0.48740452129
# 11 New best found: 0.487163667512
# 17 New best found: 0.487086040414
# 18 New best found: 0.486985414612
# 21 New best found: 0.486927360347
# 22 New best found: 0.486853919338
# 24 New best found: 0.486797757963
# 26 New best found: 0.486707044472
# 29 New best found: 0.486692765616
# Early stopping after 39 epochs
# Score is: {'loss': 0.48669276561638852, 'AUC': 0.21023435344363139}
# Fold took 127.194s
#
# Running fold 5 / 10
# 1 New best found: 0.501153646982
# 2 New best found: 0.49344681178
# 3 New best found: 0.490983006057
# 4 New best found: 0.490490274201
# 5 New best found: 0.489995865172
# 6 New best found: 0.489620952437
# 7 New best found: 0.48961216453
# 8 New best found: 0.489450325608
# 9 New best found: 0.489354215723
# 11 New best found: 0.489287437474
# 12 New best found: 0.489094770736
# 14 New best found: 0.489000018793
# 16 New best found: 0.488910873569
# 20 New best found: 0.488824270855
# 21 New best found: 0.488699445275
# 28 New best found: 0.488695555288
# 30 New best found: 0.488431957048
# 39 New best found: 0.488298280642
# Early stopping after 49 epochs
# Score is: {'loss': 0.48829828064155612, 'AUC': 0.21212924004132605}
# Fold took 163.183s
#
# Running fold 6 / 10
# 1 New best found: 0.503016638283
# 2 New best found: 0.492360710029
# 3 New best found: 0.490204615618
# 4 New best found: 0.48967015149
# 5 New best found: 0.489143336431
# 6 New best found: 0.488962467915
# 8 New best found: 0.48849577734
# 11 New best found: 0.488295650601
# 13 New best found: 0.488249352648
# 15 New best found: 0.488177757598
# 20 New best found: 0.488073965552
# 23 New best found: 0.48803814171
# 25 New best found: 0.488008837194
# 33 New best found: 0.48796429231
# 34 New best found: 0.487926654092
# 42 New best found: 0.487743303726
# Early stopping after 52 epochs
# Score is: {'loss': 0.48774330372576824, 'AUC': 0.2114667765276711}
# Fold took 168.681s
#
# Running fold 7 / 10
# 1 New best found: 0.503537925569
# 2 New best found: 0.493425467267
# 3 New best found: 0.490516115916
# 4 New best found: 0.489829496157
# 5 New best found: 0.489466819444
# 6 New best found: 0.489025493275
# 7 New best found: 0.488677448207
# 8 New best found: 0.488666087132
# 9 New best found: 0.488608094352
# 10 New best found: 0.488504305802
# 13 New best found: 0.488311358446
# 18 New best found: 0.488271103158
# 22 New best found: 0.488139207634
# 23 New best found: 0.487932136129
# Early stopping after 33 epochs
# Score is: {'loss': 0.48793213612870334, 'AUC': 0.21154734115052121}
# Fold took 106.832s
#
# Running fold 8 / 10
# 1 New best found: 0.49811486116
# 2 New best found: 0.490967215372
# 3 New best found: 0.489956104579
# 4 New best found: 0.48926752127
# 5 New best found: 0.489228103164
# 6 New best found: 0.488684189126
# 7 New best found: 0.488228593325
# 8 New best found: 0.488215172773
# 10 New best found: 0.488127084094
# 11 New best found: 0.488007500515
# 14 New best found: 0.487992223729
# 15 New best found: 0.487967341304
# 20 New best found: 0.487918101838
# 24 New best found: 0.487732856771
# Early stopping after 34 epochs
# Score is: {'loss': 0.48773285677064626, 'AUC': 0.21131961844084257}
# Fold took 111.874s
#
# Running fold 9 / 10
# 1 New best found: 0.502585129698
# 2 New best found: 0.492968477833
# 3 New best found: 0.489567170333
# 4 New best found: 0.489018453612
# 5 New best found: 0.488392230679
# 6 New best found: 0.488100401797
# 7 New best found: 0.488065995596
# 8 New best found: 0.48767569601
# 13 New best found: 0.487529609422
# 15 New best found: 0.487453966425
# 17 New best found: 0.487363050602
# 18 New best found: 0.487211004
# 20 New best found: 0.487201131625
# 29 New best found: 0.487015288155
# 38 New best found: 0.486985802599
# Early stopping after 48 epochs
# Score is: {'loss': 0.48698580259893687, 'AUC': 0.21055326295028987}
# Fold took 149.526s
#
# Running fold 10 / 10
# 1 New best found: 0.504973300989
# 2 New best found: 0.494496665514
# 3 New best found: 0.492208301834
# 4 New best found: 0.491167292665
# 5 New best found: 0.49101225045
# 6 New best found: 0.490743060958
# 7 New best found: 0.490716051511
# 9 New best found: 0.490460633435
# 11 New best found: 0.490280020537
# 14 New best found: 0.49027050555
# 15 New best found: 0.490267310457
# 18 New best found: 0.490200202406
# 19 New best found: 0.490140513141
# 20 New best found: 0.490024724738
# 29 New best found: 0.490010083444
# 30 New best found: 0.489935474052
# Early stopping after 40 epochs
# Score is: {'loss': 0.48993547405194038, 'AUC': 0.2138616216521757}
# Fold took 129.384s
#
#
# ______________________________________
# Training finished
# Cross-validation took 1423.345s
# Mean AUC = 0.2117 +- 0.0004
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
amsScan(valData)

# %%
def scoreTest(ensemble, weights):
    testData = h5py.File(dirLoc + 'testing.hdf5', "r+")
    batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

def saveTest(cut, name):
    testData = h5py.File(dirLoc + 'testing.hdf5', "r+")
    
    data = pandas.DataFrame()
    data['EventId'] = getFeature('EventId', testData)
    data['pred_class'] = getFeature('pred', testData)
    
    data['Class'] = 'b'
    data.loc[data.pred_class >= cut, 'Class'] = 's'

    data.sort_values(by=['pred_class'], inplace=True)
    data['RankOrder']=range(1, len(data)+1)
    data.sort_values(by=['EventId'], inplace=True)

    print dirLoc + name + '_test.csv'
    data.to_csv(dirLoc + name + '_test.csv', columns=['EventId', 'RankOrder', 'Class'], index=False)

# %%
scoreTest(ensemble, weights)

# %%
saveTest(0.93784874677658081, 'Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart')

# %% [markdown]
# !kaggle competitions submit -c higgs-boson -f ../Data/Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart_test.csv -m"Day2"
