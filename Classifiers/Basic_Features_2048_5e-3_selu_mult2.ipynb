# %% [markdown]
# # Second
# batch size 2048 lr 5e-4 mult 2

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.
# /home/giles/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSelu'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 2048, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 5 features: ['jetPt', 'jetEta', 'jetMass', 'ntracks', 'ntowers']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'testing.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-7,1e-2], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 2.225s
# ______________________________________

# %%
compileArgs['lr'] = 1e-4

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=20, cosAnnealMult=2, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.491370167356
# 2 New best found: 0.489757369749
# 3 New best found: 0.489200276962
# 5 New best found: 0.489188555743
# 7 New best found: 0.488379774771
# 14 New best found: 0.488219465044
# 15 New best found: 0.488099724594
# 23 New best found: 0.487974225453
# 26 New best found: 0.487874061891
# 27 New best found: 0.487830288191
# 28 New best found: 0.487757126953
# 29 New best found: 0.487644991791
# Early stopping after 49 epochs
# Score is: {'loss': 0.48764499179099424, 'AUC': 0.21126912618246363}
# Fold took 198.543s
#
# Running fold 2 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.117076). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.494078857433
# 2 New best found: 0.492520092558
# 3 New best found: 0.491414823174
# 5 New best found: 0.490948501507
# 6 New best found: 0.490824258522
# 7 New best found: 0.490625819802
# 14 New best found: 0.490288594979
# 15 New best found: 0.490221732197
# 29 New best found: 0.490063558128
# 30 New best found: 0.490019388735
# 49 New best found: 0.489911140673
# 51 New best found: 0.489866489604
# 53 New best found: 0.489804913351
# 55 New best found: 0.48965681753
# 56 New best found: 0.489622561459
# 58 New best found: 0.489550015396
# Early stopping after 78 epochs
# Score is: {'loss': 0.48955001539604137, 'AUC': 0.21350842012629345}
# Fold took 320.197s
#
# Running fold 3 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.152583). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.49241641186
# 2 New best found: 0.490794671688
# 3 New best found: 0.48987348913
# 5 New best found: 0.489289283255
# 6 New best found: 0.488944165474
# 12 New best found: 0.488756333403
# 14 New best found: 0.488540262856
# 15 New best found: 0.488456734103
# 22 New best found: 0.488390357967
# 23 New best found: 0.488359726057
# 26 New best found: 0.488181170211
# 29 New best found: 0.488127548783
# 30 New best found: 0.48805075452
# 31 New best found: 0.488047908623
# 48 New best found: 0.4879345508
# 50 New best found: 0.487806736938
# 51 New best found: 0.487787451963
# 56 New best found: 0.487780005993
# 57 New best found: 0.487687803227
# 59 New best found: 0.487575618523
# Early stopping after 79 epochs
# Score is: {'loss': 0.4875756185230889, 'AUC': 0.2111716243457482}
# Fold took 326.833s
#
# Running fold 4 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.167794). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.491934555617
# 2 New best found: 0.489357194013
# 3 New best found: 0.488983813326
# 6 New best found: 0.488510666086
# 7 New best found: 0.487946929237
# 13 New best found: 0.487735125925
# 14 New best found: 0.487657682815
# 15 New best found: 0.487541929911
# 24 New best found: 0.487495809926
# 26 New best found: 0.487398766337
# 29 New best found: 0.487367639685
# 45 New best found: 0.487315528776
# 49 New best found: 0.487088219995
# 54 New best found: 0.486986525216
# 56 New best found: 0.486859429266
# 58 New best found: 0.48677097023
# 59 New best found: 0.486752819152
# 60 New best found: 0.486752010479
# 63 New best found: 0.486750848645
# Early stopping after 83 epochs
# Score is: {'loss': 0.4867508486448372, 'AUC': 0.21026924626642696}
# Fold took 346.253s
#
# Running fold 5 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.222018). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111544). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.495817608506
# 2 New best found: 0.490976048556
# 3 New best found: 0.490851080683
# 5 New best found: 0.490732594933
# 6 New best found: 0.490059470278
# 7 New best found: 0.489641217599
# 12 New best found: 0.489559313668
# 13 New best found: 0.489486677967
# 14 New best found: 0.489364628838
# 15 New best found: 0.489187358635
# 25 New best found: 0.488736040825
# 29 New best found: 0.48873137329
# 31 New best found: 0.488728850869
# Early stopping after 51 epochs
# Score is: {'loss': 0.488728850868654, 'AUC': 0.21263133851821925}
# Fold took 220.431s
#
# Running fold
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.221731). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.111378). Check your callbacks.
#   % delta_t_median)
#  6 / 10
# 1 New best found: 0.494825271758
# 2 New best found: 0.491356915642
# 3 New best found: 0.490202698195
# 6 New best found: 0.489289781471
# 7 New best found: 0.489090553112
# 11 New best found: 0.488980935702
# 13 New best found: 0.488872141854
# 14 New best found: 0.488711385705
# 15 New best found: 0.488628283521
# 25 New best found: 0.488477226287
# 26 New best found: 0.48843729691
# 27 New best found: 0.488173899275
# 28 New best found: 0.488165832294
# 30 New best found: 0.488141736431
# 31 New best found: 0.488134757376
# 51 New best found: 0.488067307927
# 54 New best found: 0.488064151469
# 56 New best found: 0.488009466755
# 60 New best found: 0.487963162559
# 61 New best found: 0.487934876835
# 62 New best found: 0.487928572643
# 63 New best found: 0.487927006737
# Early stopping after 83 epochs
# Score is: {'loss': 0.4879270067365699, 'AUC': 0.21168445640952094}
# Fold took 385.783s
#
# Running fold 7 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.290784). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.145896). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.493413967351
# 2 New best found: 0.490966833522
# 3 New best found: 0.489850934961
# 5 New best found: 0.489511720565
# 7 New best found: 0.488815634372
# 13 New best found: 0.488760370195
# 14 New best found: 0.488672305396
# 15 New best found: 0.488523894585
# 23 New best found: 0.488384179297
# 29 New best found: 0.488296704007
# 31 New best found: 0.488275017181
# 51 New best found: 0.48817387909
# 52 New best found: 0.487994587887
# 56 New best found: 0.487975118639
# 60 New best found: 0.487891110639
# 61 New best found: 0.487884708173
# Early stopping after 81 epochs
# Score is: {'loss': 0.48788470817308, 'AUC': 0.21152413263674041}
# Fold took 375.919s
#
# Running fold 8 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.381922). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.192436). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.491765349701
# 2 New best found: 0.490128132429
# 3 New best found: 0.489507104947
# 5 New best found: 0.48944247725
# 7 New best found: 0.488806898704
# 13 New best found: 0.488466646144
# 14 New best found: 0.488422250408
# 15 New best found: 0.488342891736
# 24 New best found: 0.488278542595
# 25 New best found: 0.488244061228
# 26 New best found: 0.488225433234
# 28 New best found: 0.488208869398
# 29 New best found: 0.488038535139
# 30 New best found: 0.488029064201
# Early stopping after 50 epochs
# Score is: {'loss': 0.4880290642007536, 'AUC': 0.21171976352269106}
# Fold took 241.451s
#
# Running fold 9 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.342550). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.172114). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.49164466713
# 3 New best found: 0.488699215463
# 6 New best found: 0.488692114392
# 7 New best found: 0.488077626798
# 12 New best found: 0.487657903544
# 13 New best found: 0.487621822783
# 15 New best found: 0.487456939
# 24 New best found: 0.487377377148
# 27 New best found: 0.487280303831
# 30 New best found: 0.487166395635
# Early stopping after 50 epochs
# Score is: {'loss': 0.48716639563455855, 'AUC': 0.21085555627685904}
# Fold took 249.082s
#
# Running fold 10 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.333647). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.167650). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.497737075123
# 2 New best found: 0.493072424423
# 3 New best found: 0.491950670542
# 6 New best found: 0.491200758957
# 7 New best found: 0.491105940033
# 13 New best found: 0.491092979921
# 14 New best found: 0.490645950962
# 15 New best found: 0.49060783943
# 25 New best found: 0.490503063967
# 26 New best found: 0.490424866733
# 28 New best found: 0.490313277933
# Early stopping after 48 epochs
# Score is: {'loss': 0.49031327793323404, 'AUC': 0.21438051291899873}
# Fold took 232.260s
#
#
# ______________________________________
# Training finished
# Cross-validation took 2898.978s
# Mean AUC = 0.2119 +- 0.0004
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 3 with loss = 0.4867508486448372
# Model 1 is 8 with loss = 0.48716639563455855
# Model 2 is 2 with loss = 0.4875756185230889
# Model 3 is 0 with loss = 0.48764499179099424
# Model 4 is 6 with loss = 0.48788470817308
# Model 5 is 5 with loss = 0.4879270067365699
# Model 6 is 7 with loss = 0.4880290642007536
# Model 7 is 4 with loss = 0.488728850868654
# Model 8 is 1 with loss = 0.48955001539604137
# Model 9 is 9 with loss = 0.49031327793323404

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, verbose=1)

# %%
print 'Training ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData)),
                                                            roc_auc_score(getFeature('targets', trainData), getFeature('pred', trainData), sample_weight=getFeature('weights', trainData)))

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, verbose=1)

# %%
print 'Testing ROC AUC: unweighted {}, weighted {}'.format(roc_auc_score(getFeature('targets', valData), getFeature('pred', valData)),
                                                           roc_auc_score(getFeature('targets', valData), getFeature('pred', valData), sample_weight=getFeature('weights', valData)))

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['gen_weight'] = getFeature('weights', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]], weightName='gen_weight')

# %%
amsScan(valData)

# %%
def scoreTest(ensemble, weights):
    testData = h5py.File(dirLoc + 'testing.hdf5', "r+")
    batchEnsemblePredict(ensemble, weights, testData, ensembleSize=10, verbose=1)

def saveTest(cut, name):
    testData = h5py.File(dirLoc + 'testing.hdf5', "r+")
    
    data = pandas.DataFrame()
    data['EventId'] = getFeature('EventId', testData)
    data['pred_class'] = getFeature('pred', testData)
    
    data['Class'] = 'b'
    data.loc[data.pred_class >= cut, 'Class'] = 's'

    data.sort_values(by=['pred_class'], inplace=True)
    data['RankOrder']=range(1, len(data)+1)
    data.sort_values(by=['EventId'], inplace=True)

    print dirLoc + name + '_test.csv'
    data.to_csv(dirLoc + name + '_test.csv', columns=['EventId', 'RankOrder', 'Class'], index=False)

# %%
scoreTest(ensemble, weights)

# %%
saveTest(0.93784874677658081, 'Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart')

# %% [markdown]
# !kaggle competitions submit -c higgs-boson -f ../Data/Day_2_Basic_Features_256_1e-3_swish_mult2_200E_normedweighted_rot_cart_test.csv -m"Day2"
