# %% [markdown]
# # Fifth
# batch size 2048 lr 1e-3 swish mult2 pca

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.
# /home/giles/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ## Options

# %%
classTrainFeatures = basic_features
classModel = 'modelSwish'
varSet = "basic_features"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 2048, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 5 features: ['jetPt', 'jetEta', 'jetMass', 'ntracks', 'ntowers']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'testing.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-7,1e-1], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 2.069s
# ______________________________________

# %%
compileArgs['lr'] = 1e-3

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=30, cosAnnealMult=2, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.503644609991
# 2 New best found: 0.491254934824
# 3 New best found: 0.49018093324
# 4 New best found: 0.489403646189
# 5 New best found: 0.489018318508
# 6 New best found: 0.488061490126
# 7 New best found: 0.487947112604
# 9 New best found: 0.48790144281
# 11 New best found: 0.487571165601
# 12 New best found: 0.487488672851
# 13 New best found: 0.48748782061
# 14 New best found: 0.487462044882
# 15 New best found: 0.487445398383
# 25 New best found: 0.487348453909
# 26 New best found: 0.487255200476
# 29 New best found: 0.487232418458
# 30 New best found: 0.487210549036
# 31 New best found: 0.487202115539
# 53 New best found: 0.487175979254
# 54 New best found: 0.487129342655
# Early stopping after 84 epochs
# Score is: {'loss': 0.48712934265474406, 'AUC': 0.21067908178170147}
# Fold took 335.796s
#
# Running fold 2 / 10
# 1 New best found: 0.502297811086
# 2 New best found: 0.492674469873
# 3 New best found: 0.491830623524
# 5 New best found: 0.490758717257
# 6 New best found: 0.490524363836
# 7 New best found: 0.490452207981
# 9 New best found: 0.490388508622
# 11 New best found: 0.490275232585
# 13 New best found: 0.489991493876
# 14 New best found: 0.489867424815
# 15 New best found: 0.489825366997
# 26 New best found: 0.489692081378
# 27 New best found: 0.48962526801
# 29 New best found: 0.489624888384
# 30 New best found: 0.489603069553
# 48 New best found: 0.489560133847
# 53 New best found: 0.489546046714
# 54 New best found: 0.489524276602
# 57 New best found: 0.489509605279
# 58 New best found: 0.489464971348
# 59 New best found: 0.489464501989
# 60 New best found: 0.489444272506
# Early stopping after 90 epochs
# Score is: {'loss': 0.48944427250574085, 'AUC': 0.21337710163142132}
# Fold took 344.226s
#
# Running fold 3 / 10
# 1 New best found: 0.502374827733
# 2 New best found: 0.49131314915
# 3 New best found: 0.490108853724
# 4 New best found: 0.489276317888
# 6 New best found: 0.488543622873
# 7 New best found: 0.488400683571
# 12 New best found: 0.488151274986
# 13 New best found: 0.487868971137
# 14 New best found: 0.487847030931
# 15 New best found: 0.487833877705
# 21 New best found: 0.487730887729
# 24 New best found: 0.487561758588
# 51 New best found: 0.487550270179
# 52 New best found: 0.487478988869
# 53 New best found: 0.487440075011
# 57 New best found: 0.487427208604
# 58 New best found: 0.487390334323
# 60 New best found: 0.48738457335
# 62 New best found: 0.487382562697
# 63 New best found: 0.487382325846
# Early stopping after 93 epochs
# Score is: {'loss': 0.48738232584577146, 'AUC': 0.21095556201197485}
# Fold took 355.412s
#
# Running fold 4 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 3 with loss = 0.4863582830194
# Model 1 is 8 with loss = 0.4868158639205716
# Model 2 is 0 with loss = 0.48712934265474406
# Model 3 is 2 with loss = 0.48738232584577146
# Model 4 is 7 with loss = 0.48748643639329015
# Model 5 is 6 with loss = 0.487599777315669
# Model 6 is 5 with loss = 0.4876407373880896
# Model 7 is 4 with loss = 0.48815149870323626
# Model 8 is 1 with loss = 0.48944427250574085
# Model 9 is 9 with loss = 0.48975056827981855

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, nFolds=nSplits, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000389687242794s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000315630030246s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000313663436761s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000310365746283s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.0003103642854s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.0003208121977s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000350653079953s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000410166492433s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000420214014246s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000410555940256s per sample

# %%
print 'Training ROC AUC {}'.format(roc_auc_score(getFeature('targets', trainData, nSplits), getFeature('pred', trainData, nSplits)))
# Out:
# Training ROC AUC 0.7901495277

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, nFolds=nSplits, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000424331023375s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000385019715401s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000377973625449s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000395457051267s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000384954161889s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000384276702086s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000392057858321s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000327928393793s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000318332363485s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000320651330376s per sample

# %%
print 'Testing ROC AUC: {}'.format(roc_auc_score(getFeature('targets', valData, nSplits), getFeature('pred', valData, nSplits)))
# Out:
# Testing ROC AUC: 0.787347798892

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData, nLoad=nSplits)

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]])
