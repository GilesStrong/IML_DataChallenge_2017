# %% [markdown]
# # Sixth
# batch size 2048 lr 1e-3 swish mult2, filtered HL features

# %% [markdown]
# ### Import modules

# %%
# %matplotlib inline
from __future__ import division
import sys
import os
os.environ['MKL_THREADING_LAYER']='GNU'
sys.path.append('../')
from Modules.Basics import *
from Modules.Class_Basics import *
# Out:
# /home/giles/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/giles/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# Using TensorFlow backend.

# %% [markdown]
# ## Options

# %%
classTrainFeatures = filtered_features_0
classModel = 'modelSwish'
varSet = "filtered_features_0"

nSplits = 10
ensembleSize = 10
ensembleMode = 'loss'

maxEpochs = 200
compileArgs = {'loss':'binary_crossentropy', 'optimizer':'adam'}
trainParams = {'epochs' : 1, 'batch_size' : 2048, 'verbose' : 0}
modelParams = {'version':classModel, 'nIn':len(classTrainFeatures), 'compileArgs':compileArgs}

print "\nTraining on", len(classTrainFeatures), "features:", [var for var in classTrainFeatures]
# Out:
# Training on 29 features: ['ntracks', 'ntowers', 'jetMass', 'jetPt', 'max_track_pT', 'max_track_eta', 'min_track_eta', 'sum_tower_Ehad', 'max_tower_E', 'sum_track_pT', 'mean_tower_Eem', 'mean_track_pT', 'tower_Eem_frac', 'min_track_pT', 'sum_tower_Eem', 'min_tower_E', 'jetPhi', 'sum_tower_E', 'min_tower_eta', 'tower_Ehad_frac', 'max_tower_Eem', 'mean_tower_E', 'max_tower_Ehad', 'max_tower_eta', 'mean_tower_eta', 'jetEta', 'mean_tower_Ehad', 'mean_track_eta', 'min_tower_Eem']

# %% [markdown]
# ## Import data

# %%
trainData = h5py.File(dirLoc + 'train.hdf5', "r+")
valData = h5py.File(dirLoc + 'testing.hdf5', "r+")

# %% [markdown]
# ## Determine LR

# %%
lrFinder = batchLRFindClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, lrBounds=[1e-7,1e-1], trainOnWeights=False, verbose=0)
# Out:
# 2 classes found, running in binary mode
#
#
# ______________________________________
# Training finished
# Cross-validation took 1.961s
# ______________________________________

# %%
compileArgs['lr'] = 5e-2

# %% [markdown]
# ## Train classifier

# %%
results, histories = batchTrainClassifier(trainData, nSplits, getClassifier, modelParams, trainParams, patience=40, cosAnnealMult=2, trainOnWeights=False, maxEpochs=maxEpochs, verbose=1)
# Out:
# Using cosine annealing
# Running fold 1 / 10
# 2 classes found, running in binary mode
#
# 1 New best found: 0.500019768593
# 2 New best found: 0.486725482032
# 3 New best found: 0.483692432581
# 6 New best found: 0.482490964248
# 7 New best found: 0.481938798401
# 13 New best found: 0.481548811644
# 14 New best found: 0.481017977298
# 15 New best found: 0.480981886639
# 26 New best found: 0.480817087072
# 28 New best found: 0.480610582508
# 29 New best found: 0.48033739434
# 30 New best found: 0.480268867462
# 31 New best found: 0.480259549185
# Early stopping after 71 epochs
# Score is: {'loss': 0.4802595491852424, 'AUC': 0.2030858349237703}
# Fold took 261.033s
#
# Running fold 2 / 10
# 1 New best found: 0.539493942007
# 2 New best found: 0.493546999416
# 3 New best found: 0.488489886775
# 4 New best found: 0.486753288705
# 5 New best found: 0.485372022601
# 6 New best found: 0.484793059573
# 7 New best found: 0.484546654939
# 12 New best found: 0.484299081412
# 13 New best found: 0.483896995085
# 14 New best found: 0.483804475943
# 15 New best found: 0.483522617931
# 25 New best found: 0.48327256281
# 26 New best found: 0.483255376884
# 29 New best found: 0.482794994239
# 30 New best found: 0.482782547902
# Early stopping after 70 epochs
# Score is: {'loss': 0.4827825479021608, 'AUC': 0.20595950811541486}
# Fold took 280.087s
#
# Running fold 3 / 10
# 1 New best found: 0.49826659794
# 3 New best found: 0.489373400966
# 4 New best found: 0.487095581457
# 5 New best found: 0.485833669275
# 6 New best found: 0.484594893647
# 7 New best found: 0.484108821127
# 12 New best found: 0.483381023545
# 13 New best found: 0.482798233964
# 14 New best found: 0.482619945373
# 15 New best found: 0.482607050087
# 27 New best found: 0.482339025973
# 28 New best found: 0.482283112959
# 29 New best found: 0.481696180502
# 30 New best found: 0.481655474837
# 31 New best found: 0.481649644357
# 58 New best found: 0.481570711862
# 60 New best found: 0.481396956479
# 61 New best found: 0.481385181992
# 62 New best found: 0.481377083138
# 63 New best found: 0.481374346037
# Early stopping after 103 epochs
# Score is: {'loss': 0.4813743460371828, 'AUC': 0.20419994179352274}
# Fold took 394.899s
#
# Running fold 4 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.127102). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0
/ 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.267791). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.134557). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.497886963198
# 2 New best found: 0.486779841935
# 3 New best found: 0.484354635385
# 5 New best found: 0.483630980956
# 6 New best found: 0.482706700431
# 7 New best found: 0.482509369381
# 13 New best found: 0.481956016214
# 14 New best found: 0.481708759497
# 15 New best found: 0.481628914407
# 26 New best found: 0.481551209679
# 28 New best found: 0.481247726124
# 29 New best found: 0.481133579375
# 30 New best found: 0.481118675548
# 31 New best found: 0.481079171245
# 57 New best found: 0.481009385815
# 58 New best found: 0.48092934503
# 61 New best found: 0.48089747186
# 62 New best found: 0.480886162409
# 63 New best found: 0.480882339351
# Early stopping after 103 epochs
# Score is: {'loss': 0.48088233935099267, 'AUC': 0.20375766040955856}
# Fold took 438.386s
#
# Running fold 10 / 10
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.283454). Check your callbacks.
#   % delta_t_median)
# /home/giles/anaconda2/lib/python2.7/site-packages/keras/callbacks.py:116: UserWarning: Method on_batch_end() is slow compared to the batch update (0.142262). Check your callbacks.
#   % delta_t_median)
# 1 New best found: 0.532815721245
# 2 New best found: 0.490300519256
# 3 New best found: 0.487343164153
# 5 New best found: 0.485508998763
# 7 New best found: 0.484617145173
# 12 New best found: 0.484054308186
# 13 New best found: 0.483859912562
# 14 New best found: 0.483617398166
# 15 New best found: 0.483402313598
# 26 New best found: 0.483093380374
# 28 New best found: 0.482712823758
# 30 New best found: 0.482712349661
# 31 New best found: 0.482675158193
# Early stopping after 71 epochs
# Score is: {'loss': 0.48267515819349305, 'AUC': 0.2056828834612061}
# Fold took 281.521s
#
#
# ______________________________________
# Training finished
# Cross-validation took 3736.832s
# Mean AUC = 0.2042 +- 0.0003
# ______________________________________

# %% [markdown]
# ## Construct ensemble

# %%
with open('train_weights/resultsFile.pkl', 'r') as fin:   
    results = pickle.load(fin)

# %%
ensemble, weights = assembleEnsemble(results, ensembleSize, ensembleMode, compileArgs)
# Out:
# Choosing ensemble by loss
# Model 0 is 5 with loss = 0.4800108649583758
# Model 1 is 0 with loss = 0.4802595491852424
# Model 2 is 3 with loss = 0.4805293414497041
# Model 3 is 8 with loss = 0.48088233935099267
# Model 4 is 6 with loss = 0.48093708123210716
# Model 5 is 2 with loss = 0.4813743460371828
# Model 6 is 4 with loss = 0.4818146982282643
# Model 7 is 9 with loss = 0.48267515819349305
# Model 8 is 1 with loss = 0.4827825479021608
# Model 9 is 7 with loss = 0.4852325296062441

# %% [markdown]
# ## Response on development data

# %%
batchEnsemblePredict(ensemble, weights, trainData, ensembleSize=10, nFolds=nSplits, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000429432157759s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000359483869265s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000366690767762s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000369843070922s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000363359445959s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000362370803502s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000364934693404s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000382972758004s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000358561103014s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000357767186019s per sample

# %%
print 'Training ROC AUC {}'.format(roc_auc_score(getFeature('targets', trainData, nSplits), getFeature('pred', trainData, nSplits)))
# Out:
# Training ROC AUC 0.79716759433

# %% [markdown]
# ## Response on val data

# %%
batchEnsemblePredict(ensemble, weights, valData, ensembleSize=10, nFolds=nSplits, verbose=1)
# Out:
# Predicting batch 1 out of 10
# Prediction took 0.000378025870533s per sample
#
# Predicting batch 2 out of 10
# Prediction took 0.000375071384398s per sample
#
# Predicting batch 3 out of 10
# Prediction took 0.000351781445992s per sample
#
# Predicting batch 4 out of 10
# Prediction took 0.000367776023794s per sample
#
# Predicting batch 5 out of 10
# Prediction took 0.000368830887789s per sample
#
# Predicting batch 6 out of 10
# Prediction took 0.000365865747308s per sample
#
# Predicting batch 7 out of 10
# Prediction took 0.000367248667845s per sample
#
# Predicting batch 8 out of 10
# Prediction took 0.000355145033191s per sample
#
# Predicting batch 9 out of 10
# Prediction took 0.000367884050202s per sample
#
# Predicting batch 10 out of 10
# Prediction took 0.000355640007835s per sample

# %%
print 'Testing ROC AUC: {}'.format(roc_auc_score(getFeature('targets', valData, nSplits), getFeature('pred', valData, nSplits)))
# Out:
# Testing ROC AUC: 0.792984988627

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Import in dataframe

# %%
def convertToDF(datafile, columns={'gen_target', 'gen_weight', 'pred_class'}, nLoad=-1):
    data = pandas.DataFrame()
    data['gen_target'] = getFeature('targets', datafile, nLoad)
    data['pred_class'] = getFeature('pred', datafile, nLoad)
    print len(data), "candidates loaded"
    return data

# %%
valData = convertToDF(valData, nLoad=nSplits)
# Out:
# 313510 candidates loaded

# %%
sigVal = (valData.gen_target == 1)
bkgVal = (valData.gen_target == 0)

# %% [markdown]
# ### MVA distributions

# %%
getClassPredPlot([valData[bkgVal], valData[sigVal]])
